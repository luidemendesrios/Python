# %% [markdown]
# <a href="https://colab.research.google.com/github/luidemendesrios/Python/blob/master/Exemplo1_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import matplotlib

import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression
x,y = make_regression(n_samples=200, n_features=1, noise=30)
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.show()
